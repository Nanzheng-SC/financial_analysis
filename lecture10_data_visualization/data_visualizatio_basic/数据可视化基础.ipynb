# %% [markdown]
# <table border=0 width="100%"><tr><td><p align="left"><img src="..\..\img\logo.png" align="left" width=300></p></td><td><font size=3><B>数据可视化基础 (郑海超)</B></font></td></tr></table>

# %% [markdown]
# # 教学内容
# - 数据可视化基础
# - matplotlib基础

# %% [markdown]
# # 绘图知识

# %% [markdown]
# ## 比较图
# - 数据项之间的比较，柱状图可以作为一种最好的办法；
# - 线型图用于一段时间内变量的可视化
# - 雷达图适用于多个变量的比较

# %% [markdown]
# 线形图设计应该注意的问题：
# - 每幅图中避免过多的线形
# - 调整比例尺度，一遍清晰地展示某种趋势
# - 如果包含多个变量，应设置图例描述每个变量
#
# <img src="../Graphics/Lesson2/Figure 2.02.png" align='left' height="400" width="500"/>

# %% [markdown]
# 柱状图设计注意事项
# - 与数据变量对应的轴应始于0
# - 只要柱状图数量较少，一遍采用水平标记
#
# <img src="../Graphics/Lesson2/Figure 2.05.png" align='left' height="400" width="500"/>

# %% [markdown]
# 雷达图的设计需要注意的问题
# - 一张雷达图显示的元素要少于10个。
# - 对于多个分组的，建议如下图分开方式，提高清晰度
#
# <img src="../Graphics/Lesson2/Figure 2.08.png" align='left' height="400" width="500"/>

# %% [markdown]
# ## 关系图
# - 散点图可以对两个变量的相关性进行可视化
# - 气泡图则可以用于显示3个变量间的关系
# - 热图可以显示模式或者两个定性变量间的相关性

# %% [markdown]
# 散点图注意事项
# - 两个轴都从0开始进而准确地表达数据
# - 针对数据点使用不同的颜色。
#
# <img src="../Graphics/Lesson2/Figure 2.13.png" align='left' height="400" width="500"/>

# %% [markdown]
# 气泡图中不建议使用过多的数据量
#
# <img src="../Graphics/Lesson2/Figure 2.15.png" align='left' height="400" width="500"/>

# %% [markdown]
# 相关图 - 散点图与直方图的组合
#
# <img src="../Graphics/Lesson2/Figure 2.17.png" align='left' height="400" width="500"/>

# %% [markdown]
# 热图 - 矩阵中包含的数值表示为颜色，对于可视化多变量数据非常有用
#
# <img src="../Graphics/Lesson2/Figure 2.19.png" align='left' height="400" width="500"/>

# %% [markdown]
# ## 合成图
#
# - 可以使用饼图、堆叠柱状图

# %% [markdown]
# 饼图设计注意事项
# - 以尺寸的升序或降序，顺时针或逆时针设置切片
# - 确保每个切片包含不同的颜色
#
# <img src="../Graphics/Lesson2/Figure 2.22.png" align='left' height="400" width="500"/>

# %% [markdown]
# 堆叠式柱状图
# - 可以显示子类别相对于整个类别的比例。
# - 可以显示总量，也可以比较每个分组的百分比。
#
# <img src="../Graphics/Lesson2/Figure 2.25.png" align='left' height="400" width="500"/>

# %% [markdown]
# <img src="../Graphics/Lesson2/Figure 2.26.png" align='left' height="400" width="500"/>

# %% [markdown]
# 思考：下面的图是根据订阅者数量来展示排名前30位的YouTube的用户，你认为该如何改进？
#
# <img src="../Graphics/Lesson2/Figure 2.43.png" align='left' height="400" width="500"/>

# %% [markdown]
# ## 分布图
# - 直方图，单变量的分布状态
#
# <img src="../Graphics/Lesson2/Figure 2.31.png" align='left' height="400" width="500"/>

# %% [markdown]
# 密度图 - 与直方图相比，密度图的优点在于更善于确定分布形状。
#
# <img src="../Graphics/Lesson2/Figure 2.33.png" align='left' height="400" width="500"/>

# %% [markdown]
# 箱型图 - 可以显示中位数、25%、75%分位数，也可以显示异常值
#
# <img src="../Graphics/Lesson2/Figure 2.35.png" align='left' height="400" width="500"/>

# %% [markdown]
# 小提琴图 - 箱型图和密度图相结合
#
# <img src="../Graphics/Lesson2/Figure 2.38.png" align='left' height="400" width="500"/>

# %% [markdown]
# ## 地理图
#
# 可视化空间数据。
#
# 点图 - 每个点表示相同的尺寸和数值。
#
# - 避免显示过多的位置。
#
# <img src="../Graphics/Lesson2/Figure 2.40.png" align='left' height="400" width="500"/>

# %% [markdown]
# 等值区域图
# - 使用较深的颜色表示较高值
# - 限制颜色的渐变层次
#
# <img src="../Graphics/Lesson2/Figure 2.41.png" align='left' height="400" width="500"/>

# %% [markdown]
# 连接图 - 每条连线具有相同的宽度和数值。
#
# <img src="../Graphics/Lesson2/Figure 2.42.png" align='left' height="400" width="500"/>

# %% [markdown]
# 更多案例可以参考：海底的霍乱传染研究文献。

# %% [markdown]
# # Matplotlib基础

# %% [markdown]
# ## pyplot基础知识

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,4,5],[1,3,4,3],linestyle=':',marker='+')

# %% [markdown]
# 一张图可以包含多个数据集，每个数据集可以有不同的颜色、线型、标记等。

# %%
import numpy as np
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), color='r', marker='1')
plt.plot(x, np.cos(x), color='y', linestyle=':');

# %% [markdown]
# 存储图片
# - 可以使用`plt.savefig()`函数将图片保存到文件中。

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# Display an image file in a Jupyter notebook or IPython environment.

# %%
from IPython.display import Image
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
fig.savefig('my_figure.pdf')

# %% [markdown]
# ## 调整图形：坐标轴上下限

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# 还有一个方法是 plt.axis()（注意不要搞混 axes 和 axis）。通过传入[xmin, xmax, ymin, ymax] 对应的值，plt.axis() 方法可以让你用
# 一行代码设置 x 和 y 的限值

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# ## 设置图形标签

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend(loc = "upper right");

# %% [markdown]
# ## 设置双坐标轴

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x1 = np.arange(10)
y1 = x1*x1
y2 = x1

# %%
plt.plot(x1,y1,color = "r", linestyle = "--",label="y==x")
plt.plot(x1,y2,color = "b", linestyle = "-.",label="y==x")

plt.legend(loc = "upper left")

# %%
# 设置默认图标大小
plt.rcParams["figure.figsize"] = (8,6)

# %%
plt.plot(x1,y1,color = "r", linestyle = "--",label="y=x^2")
plt.xlabel("年龄")

plt.legend(loc = "upper left")
plt.twinx()
plt.plot(x1,y2,color = "b", linestyle = "-.",label="y=x")

plt.legend(loc = "lower right")
# Out:
# c:\Users\haichao\anaconda3\envs\finance\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\haichao\anaconda3\envs\finance\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 40836 (\N{CJK UNIFIED IDEOGRAPH-9F84}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\haichao\anaconda3\envs\finance\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\haichao\anaconda3\envs\finance\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 40836 (\N{CJK UNIFIED IDEOGRAPH-9F84}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 中文显示问题
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False


plt.plot(x1,y1,color = "r", linestyle = "--",label="y=x^2")
plt.xlabel("年龄")

plt.legend(loc = "upper left")
plt.twinx() # 双y轴,共享x轴
plt.plot(x1,y2,color = "b", linestyle = "-.",label="y=x")

plt.legend(loc = "lower right")

# %% [markdown]
# ## 文字与注释
#
# 案例：节假日对美国出生率的影响

# %% [markdown]
# 数据来源：https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

import numpy as np
import pandas as pd

# %%
# births = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv')
births = pd.read_csv("births.csv")
quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')
births['day'] = births['day'].astype(int)
births.index = pd.to_datetime(10000 * births.year +
100 * births.month +
births.day, format='%Y%m%d')
births_by_date = births.pivot_table('births',
[births.index.month, births.index.day])
births_by_date.index = [pd.Timestamp(2012, month, day) 
                        for (month, day) in births_by_date.index]

# %%
births.head()
# Out:
#             Unnamed: 0  year  month  day gender  births
# 1969-01-01  1969-01-01  1969      1    1      F    4046
# 1969-01-01  1969-01-01  1969      1    1      M    4440
# 1969-01-02  1969-01-02  1969      1    2      F    4454
# 1969-01-02  1969-01-02  1969      1    2      M    4548
# 1969-01-03  1969-01-03  1969      1    3      F    4548

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax);

# %% [markdown]
# 在用这样的图表达观点时，如果可以在图中增加一些注释，就更能吸引读者的注意了。可以通过 plt.text/ax.text 命令手动添加注释，它们可以在具体的 x / y 坐标点上放上文字

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)
# 在图上增加文字标签
style = dict(size=10, color='gray')
ax.text('2012-1-1', 3950, "New Year's Day", **style)
ax.text('2012-7-4', 4250, "Independence Day", ha='center', **style)
ax.text('2012-9-4', 4850, "Labor Day", ha='center', **style)
ax.text('2012-10-31', 4600, "Halloween", ha='right', **style)
ax.text('2012-11-25', 4450, "Thanksgiving", ha='center', **style)
ax.text('2012-12-25', 3850, "Christmas ", ha='right', **style)
# 设置坐标轴标题
ax.set(title='USA births by day of year (1969-1988)',
ylabel='average daily births')
# 设置x轴刻度值，让月份居中显示
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));

# %% [markdown]
# # 基本的绘图类型

# %% [markdown]
# ## 线形图

# %% [markdown]
# 操作12 - 利用线型图可视化股票走势
#
# <img src="../Graphics/Lesson2/Figure 2.02.png" align='left' height="400" width="500"/>

# %% [markdown]
# ## 柱状图

# %%
labels = ["A","B","C","D"]

# %%
x = np.arange(len(labels))

# %%
x
# Out:
# array([0, 1, 2, 3])

# %%
width = 0.4

# %%
plt.bar(x-width/2,[20,25,40,10],width=width)
plt.bar(x+width/2,[30,15,30,20],width=width)
plt.xticks(x)
ax = plt.gca() #通过plt.gca()获得当前的Axes对象ax
ax.set_xticklabels(labels)
# Out:
# [Text(0, 0, 'A'), Text(1, 0, 'B'), Text(2, 0, 'C'), Text(3, 0, 'D')]

# %% [markdown]
# # 课堂练习
# - 我们先不看solution，直接尝试完成下面的练习

# %% [markdown]
# ## 练习1：饼图
# plt.pie
#
# Exercise04

# %% [markdown]
# ## 练习2：散点图与气泡图
#
# activity17

# %% [markdown]
# # 练习3：可视化图像
#
# activity19 - 在网格中绘制多幅图像
