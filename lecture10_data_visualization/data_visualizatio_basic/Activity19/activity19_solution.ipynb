# %% [markdown]
# ## Displaying multiple images

# %% [markdown]
# In this activity, we will plot images in a grid.

# %%
# Import statements
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %% [markdown]
# Load all four images from the subfolder data.

# %%
# Load images
img_filenames = os.listdir('data')
imgs = [mpimg.imread(os.path.join('data', img_filename)) for img_filename in img_filenames]

# %%
img_filenames
# Out:
# ['photo-1.jpg', 'photo-2.jpg', 'photo-3.jpg', 'photo-4.jpg']

# %%
imgs[0].shape
# Out:
# (667, 1000, 3)

# %% [markdown]
# Visualize the images in a 2x2 grid. Remove the axes and give each image a label.

# %%
# Create subplot
fig, axes = plt.subplots(2, 2)
fig.figsize = (6, 6) #figsize 设置图形的大小，a 为图形的宽， b 为图形的高，单位为英寸
fig.dpi = 200 #dpi 为设置图形每英寸的点数
axes = axes.ravel()
# Specify labels
labels = ['coast', 'beach', 'building', 'city at night']
# Plot images
for i in range(len(imgs)):
    axes[i].imshow(imgs[i])
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    axes[i].set_xlabel(labels[i])
