# %% [markdown]
# <table border=0 width="100%"><tr><td><p align="left"><img src="..\img\logo.png" align="left" width=300></p></td><td><font size=3><B>homework in week two </B></font></td></tr></table>

# %% [markdown]
# tips
# - rename the name jupyter notebook file following the rules: **replace ID and name with your student ID and your own name**
# - submit the notebook solution on chaoxing in time

# %%
name = input("what is your name: ")

# %%
student_ID = input("what is your student ID: ")

# %%
print(name)
print(student_ID)

# %% [markdown]
# # develop a Naive Classifier  (100 points)
#
# - Data: comments, Dictionary, Lexicon
# - Each word in the lexicon is identified as being positive, negative
# - Each word in a message is checked against the lexicon, and assigned a value (-1, +1) based on the default value in the lexicon
# - the net word count of all lexicon matched words is taken, and if this value is greater than one, we sign the message as a buy, return 1. If this value is less than negative one, the message is taken to be a sell, return -1, else return 0.
# - you can use the function cut to tokenize the comments text.

# %%
# url = "http://guba.eastmoney.com/list,zssh000001.html"
url = "https://guba.eastmoney.com/list,600519.html"

# %%
import re
def download_page(url,para = None):
    import requests
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36 Edge/15.15063'}
    if para:
        response = requests.get(url,params=para,headers = headers)
    else:
        response = requests.get(url,headers = headers)
    response.encoding = response.apparent_encoding
    if response.status_code == 200:
        return response.text
    else:
        print ("failed to download the page")

# %%
# get all the conmments in the first page
html = download_page(url)

# %%
# print(html)

# %% [markdown]
# <tr class="listitem "><td><div class="read">1</div></td><td><div class="reply">0</div></td><td><div class="title"><a href="/news,zssh000001,1610656649.html" class="PO" data-cntitle="这指数冲到一万也白搭，个股不涨有毛用" title="这指数冲到一万也白搭，个股不涨有毛用">这指数冲到一万也白搭，个股不涨有毛用</a></div></td><td><div class="author cl"><a class="nametext fl " href="//i.eastmoney.com/7900094390809092">品味人考虑考虑8172</a><span class="jvbox fl"> </span></div></td><td><div class="update mod_time">10-15 10:03</div></td></tr>

# %%
# get all the conmments in the first page
html = download_page(url)
pattern = r"""(<tr class="listitem">.*?</tr>)"""
comments_list = re.findall(pattern,html,re.DOTALL)
# title_pattern = r"""<span class="l3 a3">.*?<a .*?href=".*?" title="(.*?)">.*?</a></span>"""
# comments = []
# for c in comments_list:
#     t = re.findall(title_pattern,c)
#     comments.append(t[0])

# %%
print(comments_list)
# Out:
# ['<tr class="listitem"><td><div class="read">1026</div></td><td><div class="reply">33</div></td><td><div class="title"><a data-postid="1610489781" data-posttype="20" href="//caifuhao.eastmoney.com/news/20251014220543577023510">A股：昨天跳空低开高走，今天跳空高开低走，明天是走是留？10.15怎么走上重点。</a></div></td><td><div class="author"><a href="//i.eastmoney.com/6894013850123560">股林太极</a></div></td><td><div class="update">10-14 10:05</div></td></tr>', '<tr class="listitem"><td><div class="read">313</div></td><td><div class="reply">4</div></td><td><div class="title"><a data-postid="1610431872" data-posttype="20" href="//caifuhao.eastmoney.com/news/20251014175920714359330">10.15盘前策略：恐慌了吗？明天又是机会！</a></div></td><td><div class="author"><a href="//i.eastmoney.com/1918013713919880">股道强心针备用</a></div></td><td><div class="update">10-14 05:59</div></td></tr>', '<tr class="listitem"><td><div class="read">1</div></td><td><div class="reply">0</div></td><td><div class="title"><a data-postid="1610803270" data-posttype="20" href="/
# ...

# %%
# data
positive_lexicon = ["起飞","买入","反弹","筑底","必涨","涨停","井喷","上行","加仓","看多","拉起来"]
negative_lexicon = ["拜拜","被套","恶心","完了","清仓","接盘","跳水","风险","下跌","砸盘"]

# %%
for c in comments:
    score = 0 # initialized value for score of comment c
    # start coding here

    print("sentiment score:",score, end=" ")
    print(c)
