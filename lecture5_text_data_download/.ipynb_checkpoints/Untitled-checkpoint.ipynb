# %%
def func(*p):
    return sum(p)

# %%
func(1,2,3)
# Out:
# 6

# %%
import numpy as np
def percents(s,places=2):
    return np.round(s/sum(s) * 100, places)

# %%
percents(np.array([2,5,8]),3)
# Out:
# array([13.333, 33.333, 53.333])

# %%
sum()
# Out:
# 15

# %%
s/sum(s)*100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d7eef847cc0f> in <module>
# ----> 1 s/sum(s)*100
#
# TypeError: 'function' object is not iterable
