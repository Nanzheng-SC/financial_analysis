# %% [markdown]
# <table border=0 width="100%"><tr><td><p align="left"><img src="..\img\logo.png" align="left" width=300></p></td><td><font size=5><B> 大模型API接入(郑海超)</B></font></td></tr></table>

# %% [markdown]
# # 课程内容
# - 大模型的应用：辅助企业降本增效
# - 使用大模型API做应用开发：品牌设计

# %% [markdown]
# # 大模型的应用

# %% [markdown]
# https://www.zbj.com/xq/f9KDthjKtKJ75i3W.html

# %% [markdown]
# 需求标题：品牌起名
#
# 需求描述：
#
# 有奖征集|征集品牌名|户外露营类目品牌
# 老板👤想要做一个露营品牌！各位在座的刘亦菲、彭于晏、Angelababy、易烊千玺们！能请你们帮忙想想吗？！
#
# 名字要有趣的！有意义的！最好中英文结合！
#
# 目前名字的几个思考方向：
#
# 1.和北欧、北有关，例如维京人
#
# 2.和麓有关，取自：林深时见麓
#
# 3.和诗词有关，例如山扉，指山野人家的柴门，原诗句：荷影侵池浪,云色入山扉
#
# 4.由有意义的几个英文单词开头取名，例如tawa
#
# 5.根据“露营是成年人的过家家”来起童真有趣的名
#
# 6.跟“马”组合的品牌名称更佳。例如：爱马仕
#
# 预算金额：
# ￥200元

# %% [markdown]
# # 使用大模型API开发应用 - 以豆包大模型为例

# %% [markdown]
# https://console.volcengine.com/auth/login?redirectURI=%2Fark%2Fregion%3Aark%2Bcn-beijing%2Fendpoint%3Fconfig%3D%257B%257D

# %% [markdown]
# ## 准备工作
# - 登录[火山引擎](https://console.volcengine.com/auth/login?redirectURI=%2Fark%2Fregion%3Aark%2Bcn-beijing%2Fendpoint%3Fconfig%3D%257B%257D)
# - 开通模型
# - 获取大模型API密钥

# %% [markdown]
# ## 保存API密钥

# %% [markdown]
# ### 方法1：直接拷贝字符串

# %%
Doubao_API_KEY = "your-apikey"

# %% [markdown]
# ### 方法3：存储到.env文件

# %%
# !conda install python-dotenv

# %%
from dotenv import load_dotenv
import os

# %%
# 使用load_dotenv()将.env文件的键值对导入到环境变量
load_dotenv()
# Out:
# True

# %%
Doubao_API_KEY = os.getenv('Doubao_API_KEY')

# %% [markdown]
# ## 使用大模型API

# %%
# !pip install --upgrade "openai>=1.0"
# Out:
# Requirement already satisfied: openai>=1.0 in c:\users\haichao\anaconda3\lib\site-packages (1.12.0)
# Collecting openai>=1.0
#   Downloading openai-2.6.0-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 872.2 kB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\haichao\anaconda3\lib\site-packages (from openai>=1.0) (3.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\haichao\anaconda3\lib\site-packages (from openai>=1.0) (4.15.0)
# Requirement already satisfied: sniffio in c:\users\haichao\anaconda3\lib\site-packages (from openai>=1.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\haichao\anaconda3\lib\site-packages (from openai>=1.0) (4.66.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\haichao\anaconda3\lib\site-packages (from openai>=1.0) (0.28.1)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.11.1-cp39-cp39-win_amd64.whl (207 kB)
#      -------------------------------------- 207.6/207.6 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\haichao\anaconda3\lib\site-packages (from openai>=1.0) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\haichao\anaconda3\lib\site-packages (from openai>=1.0) (2.12.3)
# Requirement already satisfied: idna>=2.8 in c:\users\haichao\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.0) (3.6)
# Requirement already satisfied: httpcore==1.* in c:\users\haichao\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0) (1.0.2)
# Requirement already satisfied: certifi in c:\users\haichao\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0) (2024.2.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\haichao\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0) (0.14.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\haichao\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.0) (2.41.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\haichao\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.0) (0.6.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\haichao\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai>=1.0) (0.4.2)
# Requirement already satisfied: colorama in c:\users\haichao\anaconda3\lib\site-packages (from tqdm>4->openai>=1.0) (0.4.5)
# Installing collected packages: jiter, openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.12.0
#     Uninstalling openai-1.12.0:
#       Successfully uninstalled openai-1.12.0
# Successfully installed jiter-0.11.1 openai-2.6.0
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.0.8 requires openai<2.0.0,>=1.10.0, but you have openai 2.6.0 which is incompatible.
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\haichao\anaconda3\lib\site-packages)

# %%
import os
from openai import OpenAI

# 初始化Openai客户端，从环境变量中读取您的API Key
client = OpenAI(
    # 此为默认路径，您可根据业务所在地域进行配置
    base_url="https://ark.cn-beijing.volces.com/api/v3",
    # 从环境变量中获取您的 API Key
    api_key=Doubao_API_KEY,
)

# Non-streaming:
completion = client.chat.completions.create(
    # 指定您创建的方舟推理接入点 ID，此处已帮您修改为您的推理接入点 ID
    model="doubao-1-5-pro-32k-250115",
    messages=[
        {"role": "system", "content": "你是人工智能助手"},
        {"role": "user", "content": "给我写一个关于金融数据分析方面的joke"},
    ],
)

# %%
print(completion.choices[0].message.content)
# Out:
# ### 《金融数据的“神秘预言”》
#
# 一天，两位金融分析师在办公室里对着电脑屏幕上密密麻麻的金融数据愁眉苦脸。
#
# 分析师A看着那些不断跳动的数字，抓狂地说：“这些金融数据就像神秘的密码，我感觉我是在破解外星人发来的信号，可就是搞不懂它们到底想说啥！”
#
# 分析师B无奈地耸耸肩，说：“是啊，每次我以为我从这些数据里看出了点趋势，结果市场就像个调皮的孩子，立马给我来个大反转，打得我措手不及。”
#
# 这时候，公司里那个总是有点神神叨叨的老分析师慢悠悠地走过来，神秘兮兮地说：“你们啊，还是太年轻。我跟你们说，我最近发现了一个超级准确的金融数据预测方法。”
#
# A和B眼睛一下子亮了，赶紧凑过去问：“啥方法？快教教我们！”
#
# 老分析师清了清嗓子，一本正经地说：“你们看啊，我每天早上出门，先观察我家楼下那只流浪猫。如果它是往左边走，那当天股市肯定涨；要是往右边走，那股市就跌。”
#
# A和B一脸惊愕，A忍不住说：“这……这也太扯了吧，这和金融数据有啥关系啊？”
#
# 老分析师得意地笑了笑，说：“嘿，你还别不信。我都观察一个月了，准确率高达50%呢！比那些复杂的数据分析靠谱多了！”
#
# B哭笑不得地说：“这准确率不就是瞎猜的概率嘛！”
#
# 老分析师摆摆手，说：“哎呀，你们这些搞复杂数据分析的就是不懂，有时候简单的方法才是最有效的。说不定那只猫就是金融市场的神秘使者呢！”
#
# 就在这时，公司的交易员匆匆跑进来，大喊：“不好啦，市场突然暴跌，我们的投资损失惨重！”
#
# A和B赶紧去查看数据，而老分析师则不慌不忙地掏出手机，说：“我得赶紧看看今天早上那猫是往哪走的，看看我的预测准不准。”

# %% [markdown]
# ### 课堂练习
#
# - 请使用豆包大模型提取下面的新闻的关键词
# - 对新闻做切词

# %%
news = """刚刚，全线重挫！美联储，降息大消息！
2025年11月07日 07:22 券商中国
　　美股科技股再遭猛烈抛售。

　　隔夜美股市场，三大指数全线重挫，纳指一度大跌超2%，标普500指数跌超1%，大型科技股集体大跌，英伟达、特斯拉大跌超3%，与AI相关的个股全线崩跌，其中“AI应用股”多邻国股价暴跌超25%。

　　有分析指出，AI巨头OpenAI高管的最新言论加剧了市场对“AI泡沫”的讨论，叠加美国就业市场进一步恶化迹象，使得市场情绪愈发紧张，VIX恐慌指数大幅收涨超8%。另外，美联储降息前景的不确定性也是美股市场大跌的主要原因之一，多位官员们的最新讲话凸显了美联储内部对降息路径的重大分歧。

　　美股全线重挫

　　美东时间11月6日，美股三大股指集体低开低走，截至收盘，标普500指数跌1.12%，纳指大跌1.9%，道指跌0.84%。


　　美股大型科技股集体重挫，AMD大跌超7%，英伟达、特斯拉、高通大跌超3%、亚马逊、Meta、甲骨文跌超2%，微软、台积电ADR跌超1%，苹果、博通亦小幅收跌。

　　其中，与AI相关的个股普跌，进一步凸显了投资者对科技股高估值的担忧。AI应用股多邻国股价暴跌超25%，创有史以来最大单日跌幅。公司业绩指引不及预期，同时强调专注“用户增长”，而不是短期货币化。

　　有分析指出，OpenAI高管的最新言论引发了“AI巨头需要美国政府提供担保”的误解，加剧了市场对“AI泡沫”的讨论与担忧。

　　据悉，OpenAI首席财务官Sarah Friar在周三的一场活动中表示，公司正在寻求构建由银行、私募基金、以及联邦政府“兜底”或“担保”组成的生态体系，以帮助公司为其巨额芯片投资提供融资支持。

　　随着舆情升温，Friar周四发帖澄清，OpenAI目前并没有在寻求政府为其基建投资承诺提供“兜底”，使用“兜底”这个词导致她的本意被混淆。

　　OpenAI首席执行官奥尔特曼也解释称，公司CFO的意思是美国政府应当建立“国家战略算力储备”，大量签订算力采购协议。但这应该服务公共利益，而不是帮助某家私营公司获利。

　　随后，特朗普政府的AI顾问David Sacks回应：“联邦政府不会对AI进行救助。美国至少有5家主要前沿AI模型公司，如果一家倒闭，其他公司将取而代之。”

　　另外，美股市场大跌还受到就业市场恶化的影响。Challenger， Gray & Christmas的数据显示，当月美国企业裁员总数为153074人，主要由科技业和仓储业推动，较9月增加183%，几乎是去年同期的三倍，为2022年来10月最高。此外，2025年亦成为自2009年以来裁员最严重的一年。另据Revelio Labs最新发布的数据，美国10月非农就业减少9100人，此前一个月增加了33000人。

　　Brown Brothers Harriman & Co的Elias Haddad表示，预计美联储将在12月再次降息25个基点，因为美联储的紧缩政策可能会加剧本已脆弱的就业形势，而且通胀上行风险并未出现。

　　"""

# %%
prompt =f"请提取下面新闻的关键词:{news}"

# %%
prompt
# Out:
# '请提取下面新闻的关键词:刚刚，全线重挫！美联储，降息大消息！\n2025年11月07日 07:22 券商中国\n\u3000\u3000美股科技股再遭猛烈抛售。\n\n\u3000\u3000隔夜美股市场，三大指数全线重挫，纳指一度大跌超2%，标普500指数跌超1%，大型科技股集体大跌，英伟达、特斯拉大跌超3%，与AI相关的个股全线崩跌，其中“AI应用股”多邻国股价暴跌超25%。\n\n\u3000\u3000有分析指出，AI巨头OpenAI高管的最新言论加剧了市场对“AI泡沫”的讨论，叠加美国就业市场进一步恶化迹象，使得市场情绪愈发紧张，VIX恐慌指数大幅收涨超8%。另外，美联储降息前景的不确定性也是美股市场大跌的主要原因之一，多位官员们的最新讲话凸显了美联储内部对降息路径的重大分歧。\n\n\u3000\u3000美股全线重挫\n\n\u3000\u3000美东时间11月6日，美股三大股指集体低开低走，截至收盘，标普500指数跌1.12%，纳指大跌1.9%，道指跌0.84%。\n\n\n\u3000\u3000美股大型科技股集体重挫，AMD大跌超7%，英伟达、特斯拉、高通大跌超3%、亚马逊、Meta、甲骨文跌超2%，微软、台积电ADR跌超1%，苹果、博通亦小幅收跌。\n\n\u3000\u3000其中，与AI相关的个股普跌，进一步凸显了投资者对科技股高估值的担忧。AI应用股多邻国股价暴跌超25%，创有史以来最大单日跌幅。公司业绩指引不及预期，同时强调专注“用户增长”，而不是短期货币化。\n\n\u3000\u3000有分析指出，OpenAI高管的最新言论引发了“AI巨头需要美国政府提供担保”的误解，加剧了市场对“AI泡沫”的讨论与担忧。\n\n\u3000\u3000据悉，OpenAI首席财务官Sarah Friar在周三的一场活动中表示，公司正在寻求构建由银行、私募基金、以及联邦政府“兜底”或“担保”组成的生态体系，以帮助公司为其巨额芯片投资提供融资支持。\n\n\u3000\u3000随着舆情升温，Friar周四发帖澄清，OpenAI目前并没有在寻求政府为其基建投资承诺提供“兜底”，使用“兜底”这个词导致她的本意被混淆。\n\n\u3000\u3000OpenAI首席执行官奥尔特曼也解释称，公司CFO的意思是美国政府应当建立“国家战略算力储备”，大量签订算力采购协议。但这应该服务公共利益，而不是帮助某家私营公司获利。\n\n\u3000\u3000随后，特朗普政府的AI顾问David Sacks回应：“联邦政府不会对AI进行救助。美国至少有5家主要前沿AI模型公司，如果一家倒闭，其他公司将取而代之。”\n\n\u3000\u3000另外，美股市场大跌还受到就业市场恶化的影响。Challenger， Gray & Christmas的数据显示，当月美国企业裁员总数为153074人，主要由科技业和仓储业推动，较9月增加183%，几乎是去年同期的三倍，为2022年来10月最高。此外，2025年亦成为自2009年以来裁员最严重的一年。另据Revelio Labs最新发布的数据，美国10月非农就业减少9100人，此前一个月增加了33000人。\n\n\u3000\u3000Brown Brothers Harriman & Co的Elias Haddad表示，预计美联储将在12月再次降息25个基点，因为美联储的紧缩政策可能会加剧本已脆弱的就业形势，而且通胀上行风险并未出现。\n\n\u3000\u3000'

# %%
# Non-streaming:
completion = client.chat.completions.create(
    # 指定您创建的方舟推理接入点 ID，此处已帮您修改为您的推理接入点 ID
    model="doubao-1-5-pro-32k-250115",
    messages=[
        {"role": "system", "content": "你是人工智能助手"},
        {"role": "user", "content": prompt},
    ],
)
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Non-streaming:
# ----> 2 completion = client.chat.completions.create(
#       3     # 指定您创建的方舟推理接入点 ID，此处已帮您修改为您的推理接入点 ID
#       4     model="doubao-1-5-pro-32k-250115",
#       5     messages=[
#       6         {"role": "system", "content": "你是人工智能助手"},
#       7         {"role": "user", "content": prompt},
#       8     ],
#       9 )
#      10 print(completion.choices[0].message.content)
#
# NameError: name 'client' is not defined

# %% [markdown]
# ### 简单聊天

# %%
def doubao_chat(prompt):
    import os
    from openai import OpenAI

    # 请确保您已将 API Key 存储在环境变量 ARK_API_KEY 中
    # 初始化Openai客户端，从环境变量中读取您的API Key
    client = OpenAI(
        # 此为默认路径，您可根据业务所在地域进行配置
        base_url="https://ark.cn-beijing.volces.com/api/v3",
        # 从环境变量中获取您的 API Key
        api_key=Doubao_API_KEY,
    )

    # Non-streaming:
    completion = client.chat.completions.create(
        # 指定您创建的方舟推理接入点 ID，此处已帮您修改为您的推理接入点 ID
        model="doubao-1-5-pro-32k-250115",
        messages=[
            {"role": "system", "content": "你是人工智能助手"},
            {"role": "user", "content": prompt},
        ],
    )
    return completion.choices[0].message.content

# %%
prompt = "write a joke in financial data analysis?"

# %%
response = doubao_chat(prompt)

# %%
print(response)
# Out:
# Why did the financial data analyst bring a ladder to work?
#
# Because they heard the market was going up, and they wanted to reach those high returns! But when they got there, they found out it was just a temporary spike, and they were left hanging on the ladder like a confused monkey.
#
# Another one:
#
# A financial data analyst was trying to find a trend in the stock prices. After hours of poring over the data, they finally found a pattern. It turned out it was just the pattern of their coffee stains on the spreadsheet.
#
# And here's one more:
#
# Two financial data analysts were talking. One said, "I've analyzed this dataset so much, I think it's starting to analyze me back." The other replied, "Well, at least it won't give you a bad performance review like our boss might!"

# %% [markdown]
# ### 管理机器人的记忆

# %%
prompt = "what is the capital of China"
answer = doubao_chat(prompt = prompt)

# %%
print(answer)
# Out:
# The capital of China is Beijing.
#
# Beijing is a city with a long - standing history and rich cultural heritage. It serves as the political, cultural, international communication, and scientific - technological innovation center of China. It is home to many important national institutions, historical landmarks such as the Forbidden City, the Great Wall (nearby), and Tiananmen Square, which are well - known around the world.

# %%
doubao_chat("what did I just ask you?")
# Out:
# 'You asked "what did I just ask you?".'

# %% [markdown]
# **如何管理会话记忆**

# %%
# Initialize an empty list to store the conversation history
conversation_history = []

while True:
    # Get user input
    user_input = input("User: ")
    # Check if user wants to exit
    if user_input.lower() == 'exit':
        print("Chatbot: Goodbye!")
        break
    
    # Add the user's input to the conversation history
    conversation_history.append({"role": "user", "content": user_input})

    # Create a client instance
    client = OpenAI(
        # 此为默认路径，您可根据业务所在地域进行配置
        base_url="https://ark.cn-beijing.volces.com/api/v3",
        # 从环境变量中获取您的 API Key
        api_key=Doubao_API_KEY,
    )    
    # Call the chat.completions.create method with the conversation history
    response = client.chat.completions.create(
        model="doubao-1-5-pro-32k-250115",
        messages=conversation_history,
        temperature=0.95,
    )
    
    # Output ChatGLM’s response
    s = response.choices[0].message.content
    print("Chatbot:", s)
    
    # Add the chatbot's response to the conversation history
    conversation_history.append({"role": "assistant", "content": s})
# Out:
# User: hello
# Chatbot: Hello! How can I help you today?
# User: what is the capital of China?
# Chatbot: The capital of the People's Republic of China is Beijing.
#
# Beijing is a famous historical and cultural city with a long - standing history and rich cultural heritage. It is not only the country's political center but also a national cultural center, an international communication center, and a center for scientific and technological innovation. It is home to many well - known historical sites such as the Forbidden City, the Great Wall, and the Temple of Heaven, as well as important national institutions and modern landmarks.
# User: what did I ask you?
# Chatbot: You asked me "what is the capital of China?".
# User: what is 2323*1313?
# Chatbot: We can calculate \(2323\times1313\) as follows:
#
# First, we can rewrite \(2323 = 23\times101\) and \(1313=13\times101\)
#
# Then \(2323\times1313=(23\times101)\times(13\times101)\)
#
# According to the commutative and associative laws of multiplication \((23\times101)\times(13\times101)=(23\times13)\times(101\times101)\)
#
# We know that \(23\times13 = 299\) and \(101\times101=101\times(100 + 1)=101\times100+101\times1 = 10100+101=10201\)
#
#
# So \(2323\times1313=299\times10201\)
#
# \(299\times10201=(300 - 1)\times10201=300\times10201-1\times10201\)
#
# \(300\times10201 = 3060300\), and \(1\times10201 = 10201\)
#
#
# \(3060300-10201=3050099\)
#
#
# Another way is to use the traditional multiplication method:
#
# ```
#     2323
#   x 1313
#   ------
#     6969   (2323×3)
#    23230   (2323×10)
#   696900   (2323×300)
#  2323000   (2323×1000)
#   ------
#  3050099
# ```
#
# So \(2323\times1313 = 3050099\)
# User: bye
# Chatbot: Goodbye! If you have any other questions in the future, feel free to come back and ask me. Have a great day!
# User: exit
# Chatbot: Goodbye!

# %% [markdown]
# ## 使用LLM API做品牌设计

# %% [markdown]
# ### 品牌起名与LOGO设计描述

# %%
requirements = """
有奖征集|征集品牌名|户外露营类目品牌
老板👤想要做一个露营品牌！各位在座的刘亦菲、彭于晏、Angelababy、易烊千玺们！能请你们帮忙想想吗？！

名字要有趣的！有意义的！最好中英文结合！

目前名字的几个思考方向：

1.和北欧、北有关，例如维京人

2.和麓有关，取自：林深时见麓

3.和诗词有关，例如山扉，指山野人家的柴门，原诗句：荷影侵池浪,云色入山扉

4.由有意义的几个英文单词开头取名，例如tawa

5.根据“露营是成年人的过家家”来起童真有趣的名

6.跟“马”组合的品牌名称更佳。例如：爱马仕

"""

# %%
prompt = f"""
根据下面的任务需求描述，给我起一个最合适的品牌名字。

需求描述：{requirements}

输出要求：
- 关于品牌名称，只输出一个最合适的品牌名字。
- 我计划进一步设计该品牌的LOGO，请针对你起的品牌名称，输出LOGO设计需求描述。
"""

# %%
print(prompt)
# Out:
# 根据下面的任务需求描述，给我起一个最合适的品牌名字。
#
# 需求描述：
# 有奖征集|征集品牌名|户外露营类目品牌
# 老板👤想要做一个露营品牌！各位在座的刘亦菲、彭于晏、Angelababy、易烊千玺们！能请你们帮忙想想吗？！
#
# 名字要有趣的！有意义的！最好中英文结合！
#
# 目前名字的几个思考方向：
#
# 1.和北欧、北有关，例如维京人
#
# 2.和麓有关，取自：林深时见麓
#
# 3.和诗词有关，例如山扉，指山野人家的柴门，原诗句：荷影侵池浪,云色入山扉
#
# 4.由有意义的几个英文单词开头取名，例如tawa
#
# 5.根据“露营是成年人的过家家”来起童真有趣的名
#
# 6.跟“马”组合的品牌名称更佳。例如：爱马仕
#
#
#
# 输出要求：
# - 关于品牌名称，只输出一个最合适的品牌名字。
# - 我计划进一步设计该品牌的LOGO，请针对你起的品牌名称，输出LOGO设计需求描述。

# %%
answer = doubao_chat(prompt=prompt)

# %%
print(answer)
# Out:
# 品牌名字：Nordic Steed（北欧之马）
#
# LOGO设计需求描述：
# - **整体风格**：整体风格要体现出户外露营的自由、奔放与北欧的神秘、纯净。画面应简洁而富有现代感，同时又能传达出品牌的有趣和童真氛围。
# - **主体元素**：以一匹昂首奔腾的骏马为主体形象，马的造型要具有力量感和动感，展现出勇往直前、探索未知的精神。马的身体线条流畅，鬃毛随风飘动，体现出自由不羁的感觉。在马的周围可以添加一些北欧元素，如北极光的色彩线条、北欧风格的雪花或星星等，增添北欧的神秘氛围。
# - **色彩搭配**：主色调采用冷色调，如浅蓝色、深蓝色，代表北欧的寒冷与纯净，同时搭配一些暖色调，如橙色、黄色，象征着露营时篝火的温暖和活力。北极光的色彩可以用渐变的紫色、粉色和绿色来表现，增加画面的奇幻感。
# - **文字排版**：将英文“Nordic Steed”以艺术字体呈现，放在画面的下方或一侧。字体要简洁大气，具有现代感，颜色可以选择与主体元素相呼应的颜色。中文“北欧之马”可以用较小的字体放在英文下方，起到辅助说明的作用。
# - **图形比例**：马的形象占据画面的主要部分，大约占画面的三分之二，北欧元素和文字部分占画面的三分之一。要保证各个元素之间的比例协调，不会显得过于拥挤或空旷。

# %% [markdown]
# ### 设计LOGO

# %%
import os
from openai import OpenAI


# 请确保您已将 API Key 存储在环境变量 ARK_API_KEY 中 
# 初始化Ark客户端，从环境变量中读取您的API Key 
client = OpenAI( 
    # 此为默认路径，您可根据业务所在地域进行配置 
    base_url="https://ark.cn-beijing.volces.com/api/v3", 
    # 从环境变量中获取您的 API Key。此为默认方式，您可根据需要进行修改 
    api_key=Doubao_API_KEY, 
) 
 
imagesResponse = client.images.generate( 
    model="doubao-seedream-4-0-250828", 
    prompt=answer,
    size="2K",
    response_format="url",
    extra_body={
        "watermark": True,
    },
)

# %%
print(imagesResponse.data[0].url)
# Out:
# https://ark-content-generation-v2-cn-beijing.tos-cn-beijing.volces.com/doubao-seedream-4-0/02176128425498949a9dd8d7e745560a59439996b8ea2e02c4071_0.jpeg?X-Tos-Algorithm=TOS4-HMAC-SHA256&X-Tos-Credential=AKLTYWJkZTExNjA1ZDUyNDc3YzhjNTM5OGIyNjBhNDcyOTQ%2F20251024%2Fcn-beijing%2Ftos%2Frequest&X-Tos-Date=20251024T053743Z&X-Tos-Expires=86400&X-Tos-Signature=8c6a583f511a0a2d8080170d72a6f7d8543a8a2d7d725b8ed84107a1bdd36a99&X-Tos-SignedHeaders=host&x-tos-process=image%2Fwatermark%2Cimage_YXNzZXRzL3dhdGVybWFyay5wbmc_eC10b3MtcHJvY2Vzcz1pbWFnZS9yZXNpemUsUF8xNQ%3D%3D

# %%
print(response.data[0].url)
# Out:
# https://sfile.chatglm.cn/testpath/71d2e234-23d1-584e-94a9-4d393d7e1e51_0.png

# %% [markdown]
# # 探索更多大模型API
# - https://api-docs.deepseek.com/zh-cn/
# - https://www.moonshot.cn/
# - https://platform.openai.com/docs/overview
